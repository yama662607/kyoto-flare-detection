# %% [markdown]
# # フレア検出 学習ノート 04: 恒星ごとの特殊処理（DS Tuc A / V889 Her）
#
# このノートでは、`FlareDetector_DS_Tuc_A` / `FlareDetector_V889_Her` を題材に、
# Base クラスをどのように拡張しているかを学びます。

# %% [markdown]
# ## このノートで学ぶこと（予定）
#
# - DS Tuc A のトランジット除去ロジック（`remove`）と連星補正
# - V889 Her の高度デトレンド（`detrend_flux` のオーバーライド）
# - Base クラスとサブクラスの責務の分担をどのように設計しているか

# %% [markdown]
# ## 1. なぜ恒星ごとの実装が必要か
#
# `BaseFlareDetector` は「単一星」を前提にした共通ロジックを提供しますが、
# 実際には恒星ごとに次のような違いがあります。
#
# - 連星系かどうか（DS Tuc A は主星 + 伴星）
# - トランジットや強い系外惑星信号があるかどうか
# - 長期変動やフレアの典型的な形がどれくらい複雑か（V889 Her は強い活動星）
#
# そのため、
#
# - DS Tuc A では `remove()` と `tess_band_energy()` / `flux_diff()` をオーバーライドして
#   連星補正とトランジット除去を行う
# - V889 Her では `detrend_flux()` をオーバーライドして
#   高度なフレアキャンセル付きデトレンドを行う
#
# といった「星ごとの拡張」が入っています。
#
# このノートでは、実際のクラスを使って
#
# - DS Tuc A のトランジット除去と連星補正
# - V889 Her の高度デトレンド
#
# を、図と数値の両方から確認していきます。

# %% [markdown]
# ## 2. DS Tuc A: トランジット除去と連星補正
#
# （後で実装）

# %% [markdown]
# ## 3. V889 Her: 高度デトレンド
#
# （後で実装）

# %% [markdown]
# ## 4. Base クラスとサブクラスの責務分担の整理
#
# （後で実装）
